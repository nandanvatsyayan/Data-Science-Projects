# %% [markdown]
# <hr><h3><b>DATA READING (PHASE 1)

# %% [markdown]
# <hr>ABOUT DATASET:-</hr>
# Put simply, a recommender system functions similarly to an extremely intelligent friend that knows exactly what we like and makes suggestions for items we might like.
#
# Assume we are perusing through Spotify, Netflix, or YouTube. A recommender system considers what we have previously listened to or viewed, as well as what other users with comparable interests have found enjoyable. It then makes recommendations for new films, TV series, music, or goods based on this data.
#
# The goal of a recommender system is to help us discover new things we'll love, making our experience more enjoyable and personalized.
# <b><h5><u>The 1st dataset columns are:-</u></h5>
# <li>movie_id - A unique identifier for each movie.
# <li>title - The name of the movie.
# <li>cast - The name of lead and supporting actors.
# <li>crew - The name of Director, Editor, Composer, Writer etc.
# <h5> <u>The 2nd dataset columns are:-</u></h5>
# <li>budget - The budget in which the movie was made.
# <li>genre - The genre of the movie, Action, Comedy ,Thriller etc.
# <li>homepage - A link to the homepage of the movie.
# <li>id - This is infact the movie_id as in the first dataset.
# <li>keywords - The keywords or tags related to the movie.
# <li>original_language - The language in which the movie was made.
# <li>original_title - The title of the movie before translation or adaptation.
# <li>overview - A brief description of the movie.
# <li>popularity - A numeric quantity specifying the movie popularity.
# <li>production_companies - The production house of the movie.
# <li>production_countries - The country in which it was produced.
# <li>release_date - The date on which it was released.
# <li>revenue - The worldwide revenue generated by the movie.
# <li>runtime - The running time of the movie in minutes.
# <li>status - Whether the movie is "Released" or "Rumored".
# <li>tagline - Movie's tagline.
# <li>title - Title of the movie.
# <li>vote_average - average ratings the movie recieved.
# <li>vote_count - the count of votes recieved.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# ----------load both datasets
credits = pd.read_csv('tmdb_5000_credits.csv') #----------read the dataset 
movies = pd.read_csv('tmdb_5000_movies.csv')

display(credits.head())
display(movies.head())
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
credits.shape #----------checking the number of columns and rows in the dataset
# Out:
# (4803, 4)

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.info() #----------general information on the datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
# ------------------------descriptive statstics of the two datasets
display(movies.describe())
display(credits.describe())
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
# ---------------------check for null values
display(movies.isnull().sum())
display(credits.isnull().sum())
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64
# movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
# ----------mearge each datasets to improve data readability
movie_data= pd.merge(credits, movies, on= 'title', how= 'left')
movie_data.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew     budget  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  237000000
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...  300000000
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...  245000000
# ...

# %%
movie_data.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew', 'budget', 'genres', 'homepage',
#        'id', 'keywords', 'original_language', 'original_title', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
# -------------remove unwanted columns
movie_data.drop(['movie_id', 'crew'], axis= 1, inplace= True)
movie_data.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast     budget  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...  237000000
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...  300000000
# 2  [{"cast_id": 1, "character": "James Bond", "cr...  245000000
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...  250000000
# 4  [{"cast_id": 5, "character": "John Carter", "c...  260000000
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
# ---------------divide dataset into numerical and cartegorical columns
num = movie_data.select_dtypes(include= 'number')
cat = movie_data.select_dtypes(exclude= 'number')

display(num.head(3))
display(cat.head(3))
# Out:
#       budget      id  popularity     revenue  runtime  vote_average  \
# 0  237000000   19995  150.437577  2787965087    162.0           7.2
# 1  300000000     285  139.082615   961000000    169.0           6.9
# 2  245000000  206647  107.376788   880674609    148.0           6.3
#
#    vote_count
# 0       11800
# 1        4500
# 2        4466
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# ...

# %%
# -----------------clean the dataset 
for col in movie_data.columns:
    if movie_data[col].isnull().sum()/len(movie_data) * 100 < 30:
        if col in num.columns:
            movie_data[col].fillna(movie_data[col].median(), inplace= True)
        else:
            movie_data[col].fillna(movie_data[col].mode()[0], inplace= True)
    else:
        movie_data.drop(col, axis= 1, inplace= True)

movie_data.isnull().sum()
# Out:
# title                   0
# cast                    0
# budget                  0
# genres                  0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
# --------------further drop more columns to streamline dataset to fit output choice
movie_data.drop(['original_language'], axis= 1, inplace= True)
movie_data.columns
# Out:
# Index(['title', 'cast', 'budget', 'genres', 'id', 'keywords', 'original_title',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# <hr>It's challenging to process the vocabularies in a handful of our articles. As a result, we will choose and repopulate the top 10 pertinent data entries from the designated column. We will not make any changes to the current dataframe going forward; instead, a new dataframe will be created.
#
# <li>cast
# <li>crew
# <li>genres
# <li>keywords
# <li>production_companies
# <li>production_countries
# <li>spoken_languages

# %%
# -----------copy the dataset into a new variable so as to retain the details in the dataset
processed_data = movie_data.copy()

# %%
# -----------------import the necessary libraries
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer

# -----------drop duplicates
processed_data.drop_duplicates(inplace= True)
processed_data.isnull().sum()
# Out:
# title                   0
# cast                    0
# budget                  0
# genres                  0
# id                      0
# keywords                0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
# --------------drop the "id" column
processed_data.drop('id', axis= 1, inplace= True)

# %%
# -----------------------import the ast library to extract words literally from the column 
import ast
ast.literal_eval(processed_data["spoken_languages"][0])
# Out:
# [{'iso_639_1': 'en', 'name': 'English'},
#  {'iso_639_1': 'es', 'name': 'Español'}]

# %%
list(set([i["name"] for i in ast.literal_eval(processed_data["spoken_languages"][0])][:10]))
# Out:
# ['Español', 'English']

# %%
# --------------creating a function that will implement the codes above in order to effect the extraction
def extractor(row):
    row_list = ast.literal_eval(row)
    first_10_unique_names = set([i["name"] for i in row_list][:10])
    first_10 = ", ".join(f"{name.replace(' ', '')}" for name in first_10_unique_names)
    return first_10

# Apply the function to the column containing lists of dictionaries
processed_data['cast'] = processed_data['cast'].apply(extractor)
processed_data['genres'] = processed_data['genres'].apply(extractor)
processed_data['keywords'] = processed_data['keywords'].apply(extractor)
processed_data['spoken_languages'] = processed_data['spoken_languages'].apply(extractor)
processed_data['production_companies'] = processed_data['production_companies'].apply(extractor)
processed_data['production_countries'] = processed_data['production_countries'].apply(extractor)

# %%
processed_data.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast     budget  \
# 0  StephenLang, WesStudi, ZoeSaldana, JoelDavidMo...  237000000
# 1  KeiraKnightley, KevinMcNally, JohnnyDepp, Bill...  300000000
# 2  BenWhishaw, ChristophWaltz, DanielCraig, LéaSe...  245000000
# 3  MorganFreeman, CillianMurphy, MichaelCaine, Ma...  250000000
# 4  WillemDafoe, MarkStrong, SamanthaMorton, Domin...  260000000
#
#                                        genres  \
# 0  Fantasy, Action, Adventure, ScienceFiction
# 1                  Fantasy, Action, Adventure
# 2                    Action, Adventure, Crime
# 3              Drama, Thriller, Action, Crime
# 4           Action, Adventure, ScienceFiction
#
# ...

# %%
# -----------------extract the years from the release_dat and rename the columns
processed_data['release_date'] = processed_data['release_date'].str.split('-').str[0]
processed_data = processed_data.rename(columns={'release_date': 'year'})
processed_data.head(3)
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                                 cast     budget  \
# 0  StephenLang, WesStudi, ZoeSaldana, JoelDavidMo...  237000000
# 1  KeiraKnightley, KevinMcNally, JohnnyDepp, Bill...  300000000
# 2  BenWhishaw, ChristophWaltz, DanielCraig, LéaSe...  245000000
#
#                                        genres  \
# 0  Fantasy, Action, Adventure, ScienceFiction
# 1                  Fantasy, Action, Adventure
# 2                    Action, Adventure, Crime
#
#                                             keywords  \
# 0  society, future, spacewar, spacetravel, futuri...
# 1  eastindiatradingcompany, alliance, exoticislan...
# 2  sequel, britishsecretservice, secretagent, bas...
#
#                              original_title  \
# 0                                    Avatar
# ...

# %% [markdown]
# <hr><h3><b> EXPLORATORY DATA ANALYSIS (PHASE 2)

# %% [markdown]
# <b><li>>Visualization of the distribution of movies across different decades using a count plot. and showing the top 10 years with the highest production.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a count plot displaying the year with the highest production
year_release = processed_data['year']  # Assuming 'year' is a column in your DataFrame

# Calculate the count of movies released each year
count_year = year_release.value_counts().sort_index()

# Filter to include only the 20 most recent years
count_year = count_year[-20:]

# Identify the year with the highest production
year_with_highest_production = count_year.idxmax()

# Create a count plot
plt.figure(figsize=(12, 6))
sns.countplot(x='year', data=processed_data, order=count_year.reset_index()['year'].tolist(), color='skyblue')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Number of Movies Released')
plt.title('Distribution of Movie Releases by Year')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Highlight the year with the highest production
plt.axvline(x=year_with_highest_production, color='red', linestyle='--', linewidth=2, label=f'Highest Production Year: {year_with_highest_production}')

plt.legend()

plt.tight_layout()
plt.show()

# %%
processed_data.columns
# Out:
# Index(['title', 'cast', 'budget', 'genres', 'keywords', 'original_title',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'year', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
# ------------------Most expensive movie produced
# Sort the DataFrame by the 'budget' column and select the top 10 entries
top_10_expensive_movies = processed_data.nlargest(10, 'budget')

# Plotting
plt.figure(figsize=(12, 8))
plt.bar(top_10_expensive_movies['title'], top_10_expensive_movies['budget'], color='cyan')

# Add labels and title
plt.xlabel('Movie Title')
plt.ylabel('Budget')
plt.title('Top 10 Most Expensive Movies and Their Budgets')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# ---------------Display movie with the highest profit made
# Sort the DataFrame by the 'budget' column and select the top 10 entries
top_10_profiting_movies = processed_data.nlargest(10, 'revenue')

# Plotting
plt.figure(figsize=(12, 8))
plt.bar(top_10_profiting_movies['title'], top_10_profiting_movies['revenue'], color='red')

# Add labels and title
plt.xlabel('Movie Title')
plt.ylabel('Revenue')
plt.title('Top 10 Most Profiting Movies and Their revenue')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# -------------which movies has the highest popularity?
# Sort the DataFrame by the 'popularity' column and select the top 10 entries
top_populous_movies = processed_data.nlargest(15, 'popularity')

# Plotting
plt.figure(figsize=(12, 8))
plt.bar(top_populous_movies['title'], top_populous_movies['popularity'], color='green')

# Add labels and title
plt.xlabel('Movie Title')
plt.ylabel('Popularity')
plt.title('Top 10 Most Popular Movies and Their Popularity')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# ------------Popularity distribution
popularity_values = processed_data['popularity']
#histogram
plt.hist(popularity_values, bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Popularity Scores')
plt.ylabel('Frequency')
plt.title('Distribution of Popularity Scores')
plt.show()
plt.figure()
#density plot
popularity_values.plot(kind='density', color='green')
plt.xlabel('Popularity Scores')
plt.ylabel('Density')
plt.title('Density Plot of Popularity Scores')
plt.show()

# %%
# ----------top 5 most popular movies and vote distribution
pop = processed_data.sort_values('popularity', ascending=False).head(5)
plt.figure(figsize=(12, 6))
bars = plt.barh(pop['title'], pop['popularity'], color='skyblue')
#annotations for vote average and vote count
for bar, avg, count in zip(bars, pop['vote_average'], pop['vote_count']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, 
             f'Average Vote: {avg:.2f}\nVote Count: {count}',
             va='center', ha='left', fontsize=10, color='black')
    
plt.xlabel('Popularity')
plt.ylabel('Movie Title')
plt.title('Top 5 Most Popular Movies')
plt.gca().invert_yaxis()  #Invert y-axis to show highest popularity at the top
plt.xlim(0, max(pop['popularity']) * 1.2)
plt.tight_layout()
plt.show()

# %%
# .........Plot the trend of loudness of cost of movie productioon over decades using a line plot: 
px.line(processed_data, x='year', y='budget', title='Trend of Budget over decades')

# %%
sns.lineplot(data= processed_data, x='year', y='budget')
# Out:
# <Axes: xlabel='year', ylabel='budget'>

# %%
processed_data.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast     budget  \
# 0  StephenLang, WesStudi, ZoeSaldana, JoelDavidMo...  237000000
# 1  KeiraKnightley, KevinMcNally, JohnnyDepp, Bill...  300000000
# 2  BenWhishaw, ChristophWaltz, DanielCraig, LéaSe...  245000000
# 3  MorganFreeman, CillianMurphy, MichaelCaine, Ma...  250000000
# 4  WillemDafoe, MarkStrong, SamanthaMorton, Domin...  260000000
#
#                                        genres  \
# 0  Fantasy, Action, Adventure, ScienceFiction
# 1                  Fantasy, Action, Adventure
# 2                    Action, Adventure, Crime
# 3              Drama, Thriller, Action, Crime
# 4           Action, Adventure, ScienceFiction
#
# ...

# %%
# --------------using WordCloud to further explore the dataset
# ------------prepare data for visualization
genres=[] #-----------create a list where all genres will be stored
for genre in processed_data.genres:
    
    x=genre.split('|') #--------------split genres by "|"
    for i in x:
         if i not in genres:
            genres.append(str(i))
genres=str(genres)    
titles=[] #------------a list where all movie titles will be stored
for title in processed_data.title:
    titles.append(title[0:-7])
titles=str(titles)

# %%
from wordcloud import WordCloud #-----------import wordclod for data visualization
genre_wc=WordCloud(width=1000,height=600,background_color='magenta',min_font_size=2
                    ,min_word_length=3).generate(genres)
title_wc=WordCloud(width=1000,height=600,background_color='cyan',min_font_size=2
                    ,min_word_length=3).generate(titles)

# %%
# ----------------show the plot of all the movie genres 
plt.figure(figsize=(20,8))
plt.axis('off')
plt.title('Word Cloud Plot for Movie Genres',fontsize=20)
plt.imshow(genre_wc)

# %%
# ----------------show the plot of all the movie titles 
plt.figure(figsize=(20,8))
plt.axis('off')
plt.title('Word Cloud Plot for Movie Titles',fontsize=20)
plt.imshow(title_wc)

# %%
# Show the distribution of all 4 numerical variables in the dataset

num_data = processed_data.select_dtypes(include = 'number')

def plotter(dataframe, a, b):
    plt.figure(figsize = (15, 3))
    sns.set(style = 'darkgrid')
    plt.subplot(1, 2, 1)
    sns.distplot(num_data[a])

    plt.subplot(1, 2, 2)
    sns.boxplot(x = num_data[b])

# %%
num_data.drop('id', axis= 1, inplace= True, errors='ignore')
num_data.head(2)
# Out:
#       budget  popularity     revenue  runtime  vote_average  vote_count
# 0  237000000  150.437577  2787965087    162.0           7.2       11800
# 1  300000000  139.082615   961000000    169.0           6.9        4500

# %%
print(num_data.columns.tolist())
# Out:
# ['budget', 'popularity', 'revenue', 'runtime', 'vote_average', 'vote_count']

# %%
plotter(num_data, 'budget', 'popularity')
plotter(num_data, 'revenue', 'runtime')
plotter(num_data, 'vote_average', 'vote_count')

# %%
# Is there a relationship between sales and Profit

px.scatter(data_frame=num_data, x='budget', y='revenue', title = f"Relatonship Btw Budget and Revenue is {(num_data['budget'].corr(num_data['revenue']).round(2) * 100)}%", color = 'revenue')

# %% [markdown]
# <hr>In the context of movies, a high positive correlation between budget and revenue suggests that investing more money in the production of a movie often leads to higher returns in terms of revenue. However, correlation does not imply causation. Other factors such as marketing, star power, storyline, release timing, and audience reception also play significant roles in determining a movie's revenue.

# %%
processed_data
# Out:
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                    cast     budget  \
# 0     GiovanniRibisi, CCHPounder, LazAlonso, ZoeSald...  237000000
# 1     JohnnyDepp, ChowYun-fat, StellanSkarsgård, Kei...  300000000
# 2     LéaSeydoux, AndrewScott, RoryKinnear, DaveBaut...  245000000
# 3     GaryOldman, MarionCotillard, TomHardy, JunoTem...  250000000
# ...

# %%
processed_data.to_csv('Preprocess_MovieDataset.csv', index=False)
